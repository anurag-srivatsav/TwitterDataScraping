# %%
pip install ntscraper
# Out:
# Collecting ntscraper
#   Downloading ntscraper-0.3.12-py3-none-any.whl (11 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ntscraper) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from ntscraper) (4.12.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from ntscraper) (4.9.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->ntscraper) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ntscraper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ntscraper) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ntscraper) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ntscraper) (2024.2.2)
# Installing collected packages: ntscraper
# Successfully installed ntscraper-0.3.12

# %%
from ntscraper import Nitter

# %%
scraper = Nitter(log_level = 1,skip_instance_check= False)
# Out:
# Testing instances: 100%|██████████| 77/77 [02:15<00:00,  1.77s/it]

# %%
tweets = scraper.get_tweets("AnuragSrivatsa4",mode="user",number=10)
# Out:
# INFO:root:No instance specified, using random instance https://nitter.tux.pizza
# INFO:root:Current stats for AnuragSrivatsa4: 10 tweets, 0 threads...

# %%
from pprint import pprint
pprint(tweets['tweets'])
print()
# Out:
# [{'date': 'Feb 21, 2024 · 5:04 PM UTC',
#   'external-link': '',
#   'gifs': [],
#   'is-pinned': False,
#   'is-retweet': True,
#   'link': 'https://twitter.com/RGVzoomin/status/1760349744847851835#m',
#   'pictures': ['https://pbs.twimg.com/media/GG4EwQhboAEA1bX.jpg'],
#   'quoted-post': {},
#   'replying-to': [],
#   'stats': {'comments': 469, 'likes': 7226, 'quotes': 66, 'retweets': 799},
#   'text': '',
#   'user': {'avatar': 'https://pbs.twimg.com/profile_images/1126560917/6570_138940771232_68958601232_3505842_539965_n_bigger.jpg',
#            'name': 'Ram Gopal Varma',
#            'profile_id': '1126560917',
#            'username': '@RGVzoomin'},
#   'videos': []},
#  {'date': 'Jan 12, 2024 · 7:29 AM UTC',
#   'external-link': '',
#   'gifs': [],
#   'is-pinned': False,
#   'is-retweet': True,
#   'link': 'https://twitter.com/PrasanthVarma/status/1745709559103029313#m',
#   'pictures': [],
#   'quoted-post': {'date': 'Jan 12, 2024 · 5:57 AM UTC',
#                   'gifs': [],
#                   'link': 'https://twitter.com/AndhraBoxOffice/status/1745686511465705826#m',
#                   'pictures': [],
#                   'text': "Every Friday sees a Lot of New Star's getting born "
#                           'in this Tinsel Town!  We have a New Star Director '
#                           "and The Name's #PrasanthVarma!",
#                   'user': {'avatar': 'https://pbs.twimg.com/profile_images/915254564533628928/rtiT6j20_mini.jpg',
#                            'name': 'AndhraBoxOffice.Com',
#                            'profile_id': '915254564533628928',
#                            'username': '@AndhraBoxOffice'},
#                   'videos': ['https://video.twimg.com/ext_tw_video/1745498664586633216/pu/vid/avc1/832x480/WyvKmkp3KyilgFAW.mp4?tag=12']},
#   'replying-to': [],
#   'stats': {'comments': 57, 'likes': 11925, 'quotes': 6, 'retweets': 1249},
#   'text': '🙏🏽',
#   'user': {'avatar': 'https://pbs.twimg.com/profile_images/1747445386934206464/UdJ89nM6_bigger.jpg',
#            'name': 'Prasanth Varma',
#            'profile_id': '1747445386934206464',
#            'username': '@PrasanthVarma'},
#   'videos': []},
#  {'date': 'Jan 12, 2024 · 11:51 AM UTC',
#   'external-link': '',
#   'gifs': [],
#   'is-pinned': False,
#   'is-retweet': True,
#   'link': 'https://twitter.com/ManojMudhiraj19/status/1745775406811398654#m',
#   'pictures': [],
#   'quoted-post': {},
#   'replying-to': [],
#   'stats': {'comments': 1, 'likes': 153, 'quotes': 0, 'retweets': 36},
#   'text': '#HanuManRAMpage Everywhere 😍😍',
#   'user': {'avatar': 'https://pbs.twimg.com/profile_images/1744338363761725440/uXiV9tV0_bigger.jpg',
#            'name': 'Manoj NTR🔥ᵀʰᵒᵏᵏᵘᵏᵘⁿᵗᵘᵖᵒᵛᵃᵃˡᵉ',
#            'profile_id': '1744338363761725440',
#            'username': '@ManojMudhiraj19'},
#   'videos': ['https://video.twimg.com/ext_tw_video/1745706822529695744/pu/vid/avc1/1280x720/EprA36zALr4st53X.mp4?tag=12']},
#  {'date': 'Jan 12, 2024 · 10:04 AM UTC',
#   'external-link': '',
#   'gifs': [],
#   'is-pinned': False,
#   'is-retweet': True,
#   'link': 'https://twitter.com/TeluguOchu/status/1745748467144884469#m',
#   'pictures': [],
#   'quoted-post': {},
#   'replying-to': [],
#   'stats': {'comments': 6, 'likes': 1697, 'quotes': 1, 'retweets': 210},
#   'text': 'Take a Bow🛐 @PrasanthVarma 🔥 #Hanuman #HanuManRAMpage',
#   'user': {'avatar': 'https://pbs.twimg.com/profile_images/1760687200906424321/KfE_6_qv_bigger.jpg',
#            'name': 'Lok',
#            'profile_id': '1760687200906424321',
#            'username': '@TeluguOchu'},
#   'videos': ['https://video.twimg.com/ext_tw_video/1745748123136512000/pu/vid/avc1/1694x720/GxcjYaB5U2mlQnuo.mp4?tag=12']},
#  {'date': 'Oct 28, 2023 · 2:06 PM UTC',
#   'external-link': '',
#   'gifs': [],
#   'is-pinned': False,
#   'is-retweet': True,
#   'link': 'https://twitter.com/charanvicky_/status/1718268084593828108#m',
#   'pictures': [],
#   'quoted-post': {},
#   'replying-to': [],
#   'stats': {'comments': 1, 'likes': 1498, 'quotes': 3, 'retweets': 484},
#   'text': "Whether it's #Baahubali, RRR, kantara KGF. all of these films have "
#           'really given us an International standing.   And, Ippudu '
#           '#Kalki2898AD Ostundhi..!! 💥🔥❤️\u200d🔥 — @RanaDaggubati',
#   'user': {'avatar': 'https://pbs.twimg.com/profile_images/1758866664274214912/RKvic2OT_bigger.jpg',
#            'name': ':/',
#            'profile_id': '1758866664274214912',
#            'username': '@charanvicky_'},
#   'videos': ['https://video.twimg.com/ext_tw_video/1718267998082129921/pu/vid/avc1/1120x720/nbbs6wlbpkmWD4em.mp4?tag=12']},
#  {'date': 'Aug 9, 2023 · 6:04 PM UTC',
#   'external-link': '',
#   'gifs': [],
#   'is-pinned': False,
#   'is-retweet': True,
#   'link': 'https://twitter.com/ihteshamit/status/1689336741843648512#m',
#   'pictures': [],
#   'quoted-post': {},
#   'replying-to': [],
#   'stats': {'comments': 96, 'likes': 3220, 'quotes': 27, 'retweets': 851},
#   'text': "Canva has 125M+ active users.  But almost everyone's still stuck in "
#           'beginner mode.  Here are 7 Canva hacks everyone should know about:',
#   'user': {'avatar': 'https://pbs.twimg.com/profile_images/1734933247317151744/VzmPxSdk_bigger.jpg',
#            'name': 'Ihtesham Haider',
#            'profile_id': '1734933247317151744',
#            'username': '@ihteshamit'},
#   'videos': []},
#  {'date': 'Aug 1, 2023 · 8:10 AM UTC',
#   'external-link': '',
#   'gifs': [],
#   'is-pinned': False,
#   'is-retweet': True,
#   'link': 'https://twitter.com/HeyGen_Official/status/1686288365543428096#m',
#   'pictures': [],
#   'quoted-post': {},
#   'replying-to': [],
#   'stats': {'comments': 14, 'likes': 151, 'quotes': 9, 'retweets': 32},
#   'text': "We've got some big news. 🎉 @HeyGen_Official has partnered with "
#           '@Canva to bring our AI Avatars to your designs! 👀 Incorporate our '
#           'premium and custom AI avatars from HeyGen! 😍 Go to Canva Apps, '
#           'click on HeyGen and see what you can create!  Learn More: '
#           'https://buff.ly/3DBZzoR',
#   'user': {'avatar': 'https://pbs.twimg.com/profile_images/1676658221623156746/buSEhXK3_bigger.jpg',
#            'name': 'HeyGen',
#            'profile_id': '1676658221623156746',
#            'username': '@HeyGen_Official'},
#   'videos': ['https://video.twimg.com/ext_tw_video/1686288345398226944/pu/vid/1280x720/mEJtJq2G1L2d3ORe.mp4?tag=12']},
#  {'date': 'Aug 7, 2023 · 8:57 AM UTC',
#   'external-link': '',
#   'gifs': [],
#   'is-pinned': False,
#   'is-retweet': True,
#   'link': 'https://twitter.com/shushant_l/status/1688474356060766208#m',
#   'pictures': ['https://pbs.twimg.com/media/F26qVmkawAAcSYP.jpg'],
#   'quoted-post': {},
#   'replying-to': [],
#   'stats': {'comments': 82, 'likes': 593, 'quotes': 4, 'retweets': 155},
#   'text': 'ChatGPT is old news.  Ditch it and try these 10 AI tools instead to '
#           'save 100+ hours:',
#   'user': {'avatar': 'https://pbs.twimg.com/profile_images/1540190512149168133/Kk-j67tn_bigger.jpg',
#            'name': 'Shushant Lakhyani',
#            'profile_id': '1540190512149168133',
#            'username': '@shushant_l'},
#   'videos': []},
#  {'date': 'Jul 8, 2023 · 6:14 AM UTC',
#   'external-link': '',
#   'gifs': [],
#   'is-pinned': False,
#   'is-retweet': False,
#   'link': 'https://twitter.com/AnuragSrivatsa4/status/1677561862945402880#m',
#   'pictures': [],
#   'quoted-post': {},
#   'replying-to': [],
#   'stats': {'comments': 0, 'likes': 1, 'quotes': 0, 'retweets': 0},
#   'text': 'When a writer falls in love with you, there is no looking '
#           'back....!!                '
#           '^\u2060_\u2060_\u2060_\u2060_\u2060_\u2060_\u2060_\u2060_\u2060_\u2060^',
#   'user': {'avatar': 'https://pbs.twimg.com/profile_images/1511589209194508292/r01_zmLW_bigger.jpg',
#            'name': 'Anurag Srivatsav',
#            'profile_id': '1511589209194508292',
#            'username': '@AnuragSrivatsa4'},
#   'videos': []},
#  {'date': 'Apr 19, 2023 · 4:04 AM UTC',
#   'external-link': '',
#   'gifs': [],
#   'is-pinned': False,
#   'is-retweet': False,
#   'link': 'https://twitter.com/AnuragSrivatsa4/status/1648537925045428224#m',
#   'pictures': ['https://pbs.twimg.com/media/FuDIgJ0aEAAeuCJ.jpg'],
#   'quoted-post': {},
#   'replying-to': [],
#   'stats': {'comments': 0, 'likes': 0, 'quotes': 0, 'retweets': 0},
#   'text': 'Do you remember when you joined Twitter? I do! '
#           '#MyTwitterAnniversary',
#   'user': {'avatar': 'https://pbs.twimg.com/profile_images/1511589209194508292/r01_zmLW_bigger.jpg',
#            'name': 'Anurag Srivatsav',
#            'profile_id': '1511589209194508292',
#            'username': '@AnuragSrivatsa4'},
#   'videos': []}]

# %%
tweets['tweets']
# Out:
# [{'link': 'https://twitter.com/1_bunnyfreak/status/1752000277631086832#m',
#   'text': 'What you have cooked @PrasanthVarma You should see this 🙇🙇 #HanuMan',
#   'user': {'name': 'Dynamo 🐉🪓',
#    'username': '@1_bunnyfreak',
#    'profile_id': '1760015022003236866',
#    'avatar': 'https://pbs.twimg.com/profile_images/1760015022003236866/XK7BFAIr_bigger.jpg'},
#   'date': 'Jan 29, 2024 · 4:06 PM UTC',
#   'is-retweet': True,
#   'is-pinned': False,
#   'external-link': '',
#   'replying-to': [],
#   'quoted-post': {},
#   'stats': {'comments': 347, 'retweets': 1391, 'quotes': 488, 'likes': 6968},
#   'pictures': [],
#   'videos': ['https://video.twimg.com/ext_tw_video/1752000238259421184/pu/vid/avc1/720x1280/5-H2XYNXpVR8nEkM.mp4?tag=12'],
#   'gifs': []},
#  {'link': 'https://twitter.com/PrasanthVarma/status/1745709559103029313#m',
#   'text': '🙏🏽',
#   'user': {'name': 'Prasanth Varma',
#    'username': '@PrasanthVarma',
#    'profile_id': '1747445386934206464',
#    'avatar': 'https://pbs.twimg.com/profile_images/1747445386934206464/UdJ89nM6_bigger.jpg'},
#   'date': 'Jan 12, 2024 · 7:29 AM UTC',
#   'is-retweet': True,
#   'is-pinned': False,
#   'external-link': '',
#   'replying-to': [],
#   'quoted-post': {'link': 'https://twitter.com/AndhraBoxOffice/status/1745686511465705826#m',
#    'text': "Every Friday sees a Lot of New Star's getting born in this Tinsel Town!  We have a New Star Director and The Name's #PrasanthVarma!",
#    'user': {'name': 'AndhraBoxOffice.Com',
#     'username': '@AndhraBoxOffice',
#     'profile_id': '915254564533628928',
#     'avatar': 'https://pbs.twimg.com/profile_images/915254564533628928/rtiT6j20_mini.jpg'},
#    'date': 'Jan 12, 2024 · 5:57 AM UTC',
#    'pictures': [],
#    'videos': ['https://video.twimg.com/ext_tw_video/1745498664586633216/pu/vid/avc1/832x480/WyvKmkp3KyilgFAW.mp4?tag=12'],
#    'gifs': []},
#   'stats': {'comments': 57, 'retweets': 1248, 'quotes': 6, 'likes': 11921},
#   'pictures': [],
#   'videos': [],
#   'gifs': []},
#  {'link': 'https://twitter.com/Bittu_Tweetzz/status/1745750041866932357#m',
#   'text': '#PrashanthVarma after Blasting theatres 🚶  #Hanuman #HanuManRAMpage',
#   'user': {'name': 'Dileepuu',
#    'username': '@Bittu_Tweetzz',
#    'profile_id': '1740294422536114176',
#    'avatar': 'https://pbs.twimg.com/profile_images/1740294422536114176/5CR-FDXo_bigger.jpg'},
#   'date': 'Jan 12, 2024 · 10:10 AM UTC',
#   'is-retweet': True,
#   'is-pinned': False,
#   'external-link': '',
#   'replying-to': [],
#   'quoted-post': {},
#   'stats': {'comments': 3, 'retweets': 163, 'quotes': 1, 'likes': 1257},
#   'pictures': [],
#   'videos': ['https://video.twimg.com/ext_tw_video/1745749855757312000/pu/vid/avc1/1280x720/9y34cTSAUw2rupl3.mp4?tag=12'],
#   'gifs': []},
#  {'link': 'https://twitter.com/ManojMudhiraj19/status/1745775406811398654#m',
#   'text': '#HanuManRAMpage Everywhere 😍😍',
#   'user': {'name': 'Manoj NTR🔥ᵀʰᵒᵏᵏᵘᵏᵘⁿᵗᵘᵖᵒᵛᵃᵃˡᵉ',
#    'username': '@ManojMudhiraj19',
#    'profile_id': '1744338363761725440',
#    'avatar': 'https://pbs.twimg.com/profile_images/1744338363761725440/uXiV9tV0_bigger.jpg'},
#   'date': 'Jan 12, 2024 · 11:51 AM UTC',
#   'is-retweet': True,
#   'is-pinned': False,
#   'external-link': '',
#   'replying-to': [],
#   'quoted-post': {},
#   'stats': {'comments': 1, 'retweets': 35, 'quotes': 0, 'likes': 151},
#   'pictures': [],
#   'videos': ['https://video.twimg.com/ext_tw_video/1745706822529695744/pu/vid/avc1/1280x720/EprA36zALr4st53X.mp4?tag=12'],
#   'gifs': []},
#  {'link': 'https://twitter.com/TeluguOchu/status/1745748467144884469#m',
#   'text': 'Take a Bow🛐 @PrasanthVarma 🔥 #Hanuman #HanuManRAMpage',
#   'user': {'name': 'Lok',
#    'username': '@TeluguOchu',
#    'profile_id': '1750969342290984961',
#    'avatar': 'https://pbs.twimg.com/profile_images/1750969342290984961/860jZOzp_bigger.jpg'},
#   'date': 'Jan 12, 2024 · 10:04 AM UTC',
#   'is-retweet': True,
#   'is-pinned': False,
#   'external-link': '',
#   'replying-to': [],
#   'quoted-post': {},
#   'stats': {'comments': 6, 'retweets': 210, 'quotes': 1, 'likes': 1697},
#   'pictures': [],
#   'videos': ['https://video.twimg.com/ext_tw_video/1745748123136512000/pu/vid/avc1/1694x720/GxcjYaB5U2mlQnuo.mp4?tag=12'],
#   'gifs': []}]

# %%
elon_info = scraper.get_profile_info(username="AnuragSrivatsa4")
# Out:
# INFO:root:No instance specified, using random instance https://nitter.oksocial.net

# %%
pprint(elon_info)
# Out:
# {'bio': 'writer!!',
#  'id': '1511589123534233601',
#  'image': 'https://pbs.twimg.com/profile_images/1511589209194508292/r01_zmLW_400x400.jpg',
#  'joined': '6:18 AM - 6 Apr 2022',
#  'location': '',
#  'name': 'Anurag Srivatsav',
#  'stats': {'followers': 6,
#            'following': 50,
#            'likes': 32,
#            'media': 0,
#            'tweets': 19},
#  'username': '@AnuragSrivatsa4',
#  'website': ''}

# %%
data = {
    'link':[],
    'text':[],
    'user':[],
    'likes':[],
    'quotes':[],
    'retweets':[],
    'comments':[]
}

for tweet in tweets['tweets']:
    data['link'].append(tweet['link'])
    data['text'].append(tweet['text'])
    data['user'].append(tweet['user']['name'])
    data['likes'].append(tweet['stats']['likes'])
    data['quotes'].append(tweet['stats']['quotes'])
    data['retweets'].append(tweet['stats']['retweets'])
    data['comments'].append(tweet['stats']['comments'])

# %%
data
# Out:
# {'link': ['https://twitter.com/PrasanthVarma/status/1745709559103029313#m',
#   'https://twitter.com/ManojMudhiraj19/status/1745775406811398654#m',
#   'https://twitter.com/TeluguOchu/status/1745748467144884469#m',
#   'https://twitter.com/charanvicky_/status/1718268084593828108#m',
#   'https://twitter.com/ihteshamit/status/1689336741843648512#m',
#   'https://twitter.com/HeyGen_Official/status/1686288365543428096#m',
#   'https://twitter.com/shushant_l/status/1688474356060766208#m',
#   'https://twitter.com/AnuragSrivatsa4/status/1677561862945402880#m',
#   'https://twitter.com/AnuragSrivatsa4/status/1648537925045428224#m',
#   'https://twitter.com/AnuragSrivatsa4/status/1620857776443637766#m'],
#  'text': ['🙏🏽',
#   '#HanuManRAMpage Everywhere 😍😍',
#   'Take a Bow🛐 @PrasanthVarma 🔥 #Hanuman #HanuManRAMpage',
#   "Whether it's #Baahubali, RRR, kantara KGF. all of these films have really given us an International standing.   And, Ippudu #Kalki2898AD Ostundhi..!! 💥🔥❤️\u200d🔥 — @RanaDaggubati",
#   "Canva has 125M+ active users.  But almost everyone's still stuck in beginner mode.  Here are 7 Canva hacks everyone should know about:",
#   "We've got some big news. 🎉 @HeyGen_Official has partnered with @Canva to bring our AI Avatars to your designs! 👀 Incorporate our premium and custom AI avatars from HeyGen! 😍 Go to Canva Apps, click on HeyGen and see what you can create!  Learn More: https://buff.ly/3DBZzoR",
#   'ChatGPT is old news.  Ditch it and try these 10 AI tools instead to save 100+ hours:',
#   'When a writer falls in love with you, there is no looking back....!!                ^\u2060_\u2060_\u2060_\u2060_\u2060_\u2060_\u2060_\u2060_\u2060_\u2060^',
#   'Do you remember when you joined Twitter? I do! #MyTwitterAnniversary',
#   'Everything is not expreessable  Twitter: anurag'],
#  'user': ['Prasanth Varma',
#   'Manoj NTR🔥ᵀʰᵒᵏᵏᵘᵏᵘⁿᵗᵘᵖᵒᵛᵃᵃˡᵉ',
#   'Lok',
#   ':/',
#   'Ihtesham Haider',
#   'HeyGen',
#   'Shushant Lakhyani',
#   'Anurag Srivatsav',
#   'Anurag Srivatsav',
#   'Anurag Srivatsav'],
#  'likes': [11921, 151, 1697, 1497, 3220, 151, 593, 1, 0, 0],
#  'quotes': [6, 0, 1, 3, 27, 9, 4, 0, 0, 0],
#  'retweets': [1248, 35, 210, 484, 851, 32, 155, 0, 0, 0],
#  'comments': [57, 1, 6, 1, 96, 14, 82, 0, 0, 0]}

# %%
import pandas as pd
df = pd.DataFrame(data)
df.head()
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
#                                                 link  \
# 0  https://twitter.com/PrasanthVarma/status/17457...
# 1  https://twitter.com/ManojMudhiraj19/status/174...
# 2  https://twitter.com/TeluguOchu/status/17457484...
# 3  https://twitter.com/charanvicky_/status/171826...
# 4  https://twitter.com/ihteshamit/status/16893367...
#
#                                                 text  \
# 0                                                 🙏🏽
# 1                      #HanuManRAMpage Everywhere 😍😍
# 2  Take a Bow🛐 @PrasanthVarma 🔥 #Hanuman #HanuMan...
# 3  Whether it's #Baahubali, RRR, kantara KGF. all...
# 4  Canva has 125M+ active users.  But almost ever...
#
#                            user  likes  quotes  retweets  comments
# 0                Prasanth Varma  11921       6      1248        57
# 1  Manoj NTR🔥ᵀʰᵒᵏᵏᵘᵏᵘⁿᵗᵘᵖᵒᵛᵃᵃˡᵉ    151       0        35         1
# 2                           Lok   1697       1       210         6
# 3                            :/   1497       3       484         1
# 4               Ihtesham Haider   3220      27       851        96

# %% [markdown]
# scraping data from twitter

# %%
import pandas as pd
scraper = Nitter()
def create_tweets_dataset(username,no_of_tweets):
    tweets = scraper.get_tweets(username,mode="user",number=no_of_tweets)
    data = {
        'link':[],
        'text':[],
        'user':[],
        'likes':[],
        'quotes':[],
        'retweets':[],
        'comments':[]
    }

    for tweet in tweets['tweets']:
        data['link'].append(tweet['link'])
        data['text'].append(tweet['text'])
        data['user'].append(tweet['user']['name'])
        data['likes'].append(tweet['stats']['likes'])
        data['quotes'].append(tweet['stats']['quotes'])
        data['retweets'].append(tweet['stats']['retweets'])
        data['comments'].append(tweet['stats']['comments'])
    df = pd.DataFrame(data)
    df.to_csv(username+"_tweets_data.csv")
# Out:
# Testing instances: 100%|██████████| 77/77 [01:31<00:00,  1.19s/it]

# %%
create_tweets_dataset("MrBeast",10)
# Out:
# INFO:root:No instance specified, using random instance https://nitter.in.projectsegfau.lt
# WARNING:root:Empty page on https://nitter.in.projectsegfau.lt
#                                                 link  \
# 0  https://twitter.com/PrasanthVarma/status/17457...
# 1  https://twitter.com/ManojMudhiraj19/status/174...
# 2  https://twitter.com/TeluguOchu/status/17457484...
# 3  https://twitter.com/charanvicky_/status/171826...
# 4  https://twitter.com/ihteshamit/status/16893367...
# 5  https://twitter.com/HeyGen_Official/status/168...
# 6  https://twitter.com/shushant_l/status/16884743...
# 7  https://twitter.com/AnuragSrivatsa4/status/167...
# 8  https://twitter.com/AnuragSrivatsa4/status/164...
# 9  https://twitter.com/AnuragSrivatsa4/status/162...
#
#                                                 text  \
# 0                                                 🙏🏽
# 1                      #HanuManRAMpage Everywhere 😍😍
# 2  Take a Bow🛐 @PrasanthVarma 🔥 #Hanuman #HanuMan...
# 3  Whether it's #Baahubali, RRR, kantara KGF. all...
# 4  Canva has 125M+ active users.  But almost ever...
# 5  We've got some big news. 🎉 @HeyGen_Official ha...
# 6  ChatGPT is old news.  Ditch it and try these 1...
# 7  When a writer falls in love with you, there is...
# 8  Do you remember when you joined Twitter? I do!...
# 9    Everything is not expreessable  Twitter: anurag
#
#                            user  likes  quotes  retweets  comments
# 0                Prasanth Varma  11921       6      1248        57
# 1  Manoj NTR🔥ᵀʰᵒᵏᵏᵘᵏᵘⁿᵗᵘᵖᵒᵛᵃᵃˡᵉ    151       0        35         1
# 2                           Lok   1697       1       210         6
# 3                            :/   1497       3       484         1
# 4               Ihtesham Haider   3220      27       851        96
# 5                        HeyGen    151       9        32        14
# 6             Shushant Lakhyani    593       4       155        82
# 7              Anurag Srivatsav      1       0         0         0
# 8              Anurag Srivatsav      0       0         0         0
# 9              Anurag Srivatsav      0       0         0         0
